# %%
import os
os.environ['Gemini_API_key']='AIzaSyDrLIuo9EEFaNgA5luGwn4wsN0xqyuQtRo'

# %%
pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['Gemini_API_key'])

# %%
model=genai.GenerativeModel('gemini-2.5-flash-preview-04-17')

# %%
response=model.generate_content("give me the list of agentic ai in the market")
print(response.text)
# Out:
# Okay, defining "agentic AI in the market" can be a bit fluid, as true autonomous agents are still evolving. However, we can list tools, platforms, and frameworks that incorporate significant agentic capabilities – meaning they can understand a goal, plan steps, execute actions (often using tools), and iterate towards completion, sometimes with minimal human intervention.
#
# Here's a list categorized by their typical use case or nature:
#
# **1. Specialized Agentic AI (Designed for Specific Professions/Tasks):**
#
# *   **Devin (Cognition Labs):** Marketed as the "world's first AI software engineer." Designed to autonomously plan and execute complex software development tasks end-to-end (writing, debugging, deploying code). Currently in limited access.
# ...

# %%
import PIL.Image
img=PIL.Image.open(r"C:\Users\rahee\Downloads\img.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=390x260>

# %%
model1= genai.GenerativeModel('gemini-2.5-flash-preview-04-17')

# %%
response=model.generate_content(img)
print(response.text)
# Out:
# The image depicts a stunning landscape featuring a body of water reflecting a vibrant sunset or sunrise sky. A majestic eagle soars through the colorful clouds, its silhouette clearly visible against the bright sky. The water's surface perfectly mirrors the dramatic hues of orange, red, yellow, and teal found in the clouds above, as well as the eagle's form. In the background, dark mountains rise against the horizon, partially obscured by mist. To the right in the foreground, there are dark reeds or tall grasses adding texture to the scene. Tiny birds are also visible flying in the distance. The overall image conveys a sense of freedom, tranquility, and natural beauty.
